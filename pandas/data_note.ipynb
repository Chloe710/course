# %%
import pandas as pd
df=pd.read_excel('豆瓣250.xlsx',skiprows=1,header=None)
df
# Out:
#        0         1                         2    3          4                5  \
# 0      1    肖申克的救赎  The Shawshank Redemption  9.7  2410222.0          希望让人自由。
# 1      2      霸王别姬                        缺失  9.6  1793718.0            风华绝代。
# 2      3      阿甘正传              Forrest Gump  9.5  1814052.0        一部美国近现代史。
# 3      4   这个杀手不太冷                      Léon  9.4  1982399.0  怪蜀黍和小萝莉不得不说的故事。
# 4      5     泰坦尼克号                   Titanic  9.4  1775480.0        失去的才是永恒的。
# ..   ...       ...                       ...  ...        ...              ...
# 245  246        浪潮                 Die Welle  8.7   231540.0       世界离独裁只有五天。
# 246  247       猜火车             Trainspotting  8.5   367598.0        不可猜的青春迷笛。
# 247  248      爱乐之城                La La Land  8.4   692407.0              NaN
# 248  249  小萝莉的猴神大叔         Bajrangi Bhaijaan  8.4   418917.0       宝莱坞的萝莉与大叔。
# 249  250   背靠背，脸对脸                        缺失  9.5    75577.0              NaN
#
# ...

# %%
import pandas as pd
df=pd.read_csv('beijing_tianqi_2018.csv')
df
# Out:
#             ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0    2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1    2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2    2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3    2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4    2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
# ..          ...    ...    ...    ...       ...    ...  ...     ...       ...
# 360  2018-12-27    -5℃   -12℃   多云~晴       西北风     3级   48       优         1
# 361  2018-12-28    -3℃   -11℃      晴       西北风     3级   40       优         1
# 362  2018-12-29    -3℃   -12℃      晴       西北风     2级   29       优         1
# 363  2018-12-30    -2℃   -11℃   晴~多云       东北风     1级   31       优         1
# 364  2018-12-31    -2℃   -10℃     多云       东北风     1级   56       良         2
#
# [365 rows x 9 columns]

# %%
df.head(5)
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1

# %% [markdown]
# tail(row=5):默认查看DataFrame 的后五行数据

# %%
df.tail()
# Out:
#             ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 360  2018-12-27    -5℃   -12℃   多云~晴       西北风     3级   48       优         1
# 361  2018-12-28    -3℃   -11℃      晴       西北风     3级   40       优         1
# 362  2018-12-29    -3℃   -12℃      晴       西北风     2级   29       优         1
# 363  2018-12-30    -2℃   -11℃   晴~多云       东北风     1级   31       优         1
# 364  2018-12-31    -2℃   -10℃     多云       东北风     1级   56       良         2

# %% [markdown]
# 查看数据的整体情况

# %% [markdown]
# 1.info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 365 entries, 0 to 364
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ymd        365 non-null    object
#  1   bWendu     365 non-null    object
#  2   yWendu     365 non-null    object
#  3   tianqi     365 non-null    object
#  4   fengxiang  365 non-null    object
#  5   fengli     365 non-null    object
#  6   aqi        365 non-null    int64
#  7   aqiInfo    365 non-null    object
#  8   aqiLevel   365 non-null    int64
# dtypes: int64(2), object(7)
# memory usage: 25.8+ KB

# %%
df.describe(include='all')
# Out:
#                ymd bWendu yWendu tianqi fengxiang fengli         aqi aqiInfo  \
# count          365    365    365    365       365    365  365.000000     365
# unique         365     44     40     31         8      6         NaN       6
# top     2018-01-01    30℃    25℃      晴        南风   1-2级         NaN       良
# freq             1     18     17    101        92    236         NaN     150
# mean           NaN    NaN    NaN    NaN       NaN    NaN   82.183562     NaN
# std            NaN    NaN    NaN    NaN       NaN    NaN   51.936159     NaN
# min            NaN    NaN    NaN    NaN       NaN    NaN   21.000000     NaN
# 25%            NaN    NaN    NaN    NaN       NaN    NaN   46.000000     NaN
# 50%            NaN    NaN    NaN    NaN       NaN    NaN   69.000000     NaN
# 75%            NaN    NaN    NaN    NaN       NaN    NaN  104.000000     NaN
# max            NaN    NaN    NaN    NaN       NaN    NaN  387.000000     NaN
#
#           aqiLevel
# count   365.000000
# ...

# %%
df.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1

# %% [markdown]
# 1.把摄氏度符号去掉
#
# 2.把数据类新转为数字类型
#
# 3.相减的结果保存为新列

# %% [markdown]
# 查看列索引

# %%
df.columns
# Out:
# Index(['ymd', 'bWendu', 'yWendu', 'tianqi', 'fengxiang', 'fengli', 'aqi',
#        'aqiInfo', 'aqiLevel'],
#       dtype='object')

# %%
df['最高温度']=df['bWendu'].str.replace('℃','').astype('float64')

# %%
df.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel  \
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
#
#    最高温度
# 0   3.0
# 1   2.0
# 2   2.0
# 3   0.0
# 4   3.0

# %%
df['最低温度']=df['yWendu'].str.replace('℃','').astype('float64')
df.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel  \
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
#
#    最高温度  最低温度
# 0   3.0  -6.0
# 1   2.0  -5.0
# 2   2.0  -5.0
# 3   0.0  -8.0
# 4   3.0  -6.0

# %%
df['温差']=df['最高温度']-df['最低温度']
df.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel  \
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1
#
#    最高温度  最低温度   温差
# 0   3.0  -6.0  9.0
# 1   2.0  -5.0  7.0
# 2   2.0  -5.0  7.0
# 3   0.0  -8.0  8.0
# 4   3.0  -6.0  9.0

# %% [markdown]
# # 删除列
# drop (clo_name,inplace=True)
#     inplace=False :是否在原表做删除（如果

# %%
df.columns
# Out:
# Index(['ymd', 'bWendu', 'yWendu', 'tianqi', 'fengxiang', 'fengli', 'aqi',
#        'aqiInfo', 'aqiLevel', '最高温度', '最低温度', '温差'],
#       dtype='object')

# %%
df.drop(['bWendu','yWendu'],axis=1,inplace=True)
df.head()
# Out:
#           ymd tianqi fengxiang fengli  aqi aqiInfo  aqiLevel  最高温度  最低温度   温差
# 0  2018-01-01   晴~多云       东北风   1-2级   59       良         2   3.0  -6.0  9.0
# 1  2018-01-02   阴~多云       东北风   1-2级   49       优         1   2.0  -5.0  7.0
# 2  2018-01-03     多云        北风   1-2级   28       优         1   2.0  -5.0  7.0
# 3  2018-01-04      阴       东北风   1-2级   28       优         1   0.0  -8.0  8.0
# 4  2018-01-05   多云~晴       西北风   1-2级   50       优         1   3.0  -6.0  9.0

# %% [markdown]
# 通过选择列的方式实现删除

# %%
print(df.columns.tolist())
# Out:
# ['ymd', 'tianqi', 'fengxiang', 'fengli', 'aqi', 'aqiInfo', 'aqiLevel', '最高温度', '最低温度', '温差']

# %%
df.head()
# Out:
#           ymd tianqi fengxiang fengli  aqi aqiInfo  aqiLevel  最高温度  最低温度   温差
# 0  2018-01-01   晴~多云       东北风   1-2级   59       良         2   3.0  -6.0  9.0
# 1  2018-01-02   阴~多云       东北风   1-2级   49       优         1   2.0  -5.0  7.0
# 2  2018-01-03     多云        北风   1-2级   28       优         1   2.0  -5.0  7.0
# 3  2018-01-04      阴       东北风   1-2级   28       优         1   0.0  -8.0  8.0
# 4  2018-01-05   多云~晴       西北风   1-2级   50       优         1   3.0  -6.0  9.0

# %% [markdown]
# 修改列名   参数 : inplace =True 在原表中修改，不返回值

# %%
df.columns
# Out:
# Index(['ymd', 'tianqi', 'fengxiang', 'fengli', 'aqi', 'aqiInfo', 'aqiLevel',
#        '最高温度', '最低温度', '温差'],
#       dtype='object')

# %%
df.rename(columns={'ymd':'日期', 'tianqi':'天气情况', 'fengxiang':'风向', 'fengli':'风力', 'aqi':'空气质量指数', 'aqiInfo':'空气情况', 'aqiLevel':'空气等级'})
# Out:
#              日期  天气情况   风向    风力  空气质量指数 空气情况  空气等级  最高温度  最低温度   温差
# 0    2018-01-01  晴~多云  东北风  1-2级      59    良     2   3.0  -6.0  9.0
# 1    2018-01-02  阴~多云  东北风  1-2级      49    优     1   2.0  -5.0  7.0
# 2    2018-01-03    多云   北风  1-2级      28    优     1   2.0  -5.0  7.0
# 3    2018-01-04     阴  东北风  1-2级      28    优     1   0.0  -8.0  8.0
# 4    2018-01-05  多云~晴  西北风  1-2级      50    优     1   3.0  -6.0  9.0
# ..          ...   ...  ...   ...     ...  ...   ...   ...   ...  ...
# 360  2018-12-27  多云~晴  西北风    3级      48    优     1  -5.0 -12.0  7.0
# 361  2018-12-28     晴  西北风    3级      40    优     1  -3.0 -11.0  8.0
# 362  2018-12-29     晴  西北风    2级      29    优     1  -3.0 -12.0  9.0
# 363  2018-12-30  晴~多云  东北风    1级      31    优     1  -2.0 -11.0  9.0
# 364  2018-12-31    多云  东北风    1级      56    良     2  -2.0 -10.0  8.0
#
# [365 rows x 10 columns]

# %%
df.rename(columns={'ymd':'日期', 'tianqi':'天气情况', 
                   'fengxiang':'风向', 'fengli':'风力', 'aqi':'空气质量指数',
                     'aqiInfo':'空气情况', 'aqiLevel':'空气等级'},inplace=True)

# %%
df.head()
# Out:
#            日期  天气情况   风向    风力  空气质量指数 空气情况  空气等级  最高温度  最低温度   温差
# 0  2018-01-01  晴~多云  东北风  1-2级      59    良     2   3.0  -6.0  9.0
# 1  2018-01-02  阴~多云  东北风  1-2级      49    优     1   2.0  -5.0  7.0
# 2  2018-01-03    多云   北风  1-2级      28    优     1   2.0  -5.0  7.0
# 3  2018-01-04     阴  东北风  1-2级      28    优     1   0.0  -8.0  8.0
# 4  2018-01-05  多云~晴  西北风  1-2级      50    优     1   3.0  -6.0  9.0

# %%
df2=pd.read_csv('beijing_tianqi_2018.csv')
df2.head()
# Out:
#           ymd bWendu yWendu tianqi fengxiang fengli  aqi aqiInfo  aqiLevel
# 0  2018-01-01     3℃    -6℃   晴~多云       东北风   1-2级   59       良         2
# 1  2018-01-02     2℃    -5℃   阴~多云       东北风   1-2级   49       优         1
# 2  2018-01-03     2℃    -5℃     多云        北风   1-2级   28       优         1
# 3  2018-01-04     0℃    -8℃      阴       东北风   1-2级   28       优         1
# 4  2018-01-05     3℃    -6℃   多云~晴       西北风   1-2级   50       优         1

# %%
def fun(d):
    return float (d['bWendu'].replace ('℃','' )) - float (d['yWendu'].replace('℃', ''))
    # return float(d['bwendu'].replace('℃',''))- float (d['ywendu'].replace('℃',''))

# %%
df2.apply(fun,axis=1)
# Out:
# 0      9.0
# 1      7.0
# 2      7.0
# 3      8.0
# 4      9.0
#       ...
# 360    7.0
# 361    8.0
# 362    9.0
# 363    9.0
# 364    8.0
# Length: 365, dtype: float64

# %%
df2.apply(lambda d:float (d['bWendu'].replace ('℃','' )) - float (d['yWendu'].replace('℃', '')),axis=1)
# Out:
# 0      9.0
# 1      7.0
# 2      7.0
# 3      8.0
# 4      9.0
#       ...
# 360    7.0
# 361    8.0
# 362    9.0
# 363    9.0
# 364    8.0
# Length: 365, dtype: float64

# %%
def fun(d,h,l):
    return float(d[h].replace ('℃','' )) - float (d[l].replace('℃', ''))

# %%
df2.apply(fun,axis=1,args=('bWendu','yWendu'))
# Out:
# 0      9.0
# 1      7.0
# 2      7.0
# 3      8.0
# 4      9.0
#       ...
# 360    7.0
# 361    8.0
# 362    9.0
# 363    9.0
# 364    8.0
# Length: 365, dtype: float64

# %%
df['温差类型']=df['温差'].apply(lambda d:'温差小' if d <10 else '正常' if d ==10 else '温差大')
df.head()
# Out:
#            日期  天气情况   风向    风力  空气质量指数 空气情况  空气等级  最高温度  最低温度   温差 温差类型
# 0  2018-01-01  晴~多云  东北风  1-2级      59    良     2   3.0  -6.0  9.0  温差小
# 1  2018-01-02  阴~多云  东北风  1-2级      49    优     1   2.0  -5.0  7.0  温差小
# 2  2018-01-03    多云   北风  1-2级      28    优     1   2.0  -5.0  7.0  温差小
# 3  2018-01-04     阴  东北风  1-2级      28    优     1   0.0  -8.0  8.0  温差小
# 4  2018-01-05  多云~晴  西北风  1-2级      50    优     1   3.0  -6.0  9.0  温差小

# %% [markdown]
# 根据温差类型分析

# %%
data= df['温差类型'].value_counts()
data
# Out:
# 温差大    178
# 温差小    143
# 正常      44
# Name: 温差类型, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family']='SimHei' # 解决画图中乱码的问题
plt.rcParams['axes.unicode_minus']=False # 用来正常显示正负号

# %%
a=plt.bar(data.index, data.values)
a=plt.title('温差类型对比分析',color='red',size=20)
a=plt.show()

# %%
from pyecharts.charts import Bar
import pyecharts.options as opts

# %%
c=(
    Bar() # 创建柱状图对象
    .add_xaxis(data.index.tolist())
    .add_yaxis('温差类型',data.values.tolist())
    .set_global_opts(
        title_opts=opts.TitleOpts (title="温差类型对比分析") # 标题配置项) # 全剧配置项
    
    # .render("bar base.html") # 把图表绘制到HTML文件
    ))
c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/v5/echarts.min'
#         }
#     });
# </script>
#
#         <div id="386e4df57b084bdb90ffbcb79936c4d8" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_386e4df57b084bdb90ffbcb79936c4d8 = echarts.init(
#                     document.getElementById('386e4df57b084bdb90ffbcb79936c4d8'), 'white', {renderer: 'canvas'});
#                 var option_386e4df57b084bdb90ffbcb79936c4d8 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "aria": {
#         "enabled": false
#     },
#     "color": [
#         "#5470c6",
#         "#91cc75",
#         "#fac858",
# ...

# %%
df.head()
# Out:
#            日期  天气情况   风向    风力  空气质量指数 空气情况  空气等级  最高温度  最低温度   温差 温差类型
# 0  2018-01-01  晴~多云  东北风  1-2级      59    良     2   3.0  -6.0  9.0  温差小
# 1  2018-01-02  阴~多云  东北风  1-2级      49    优     1   2.0  -5.0  7.0  温差小
# 2  2018-01-03    多云   北风  1-2级      28    优     1   2.0  -5.0  7.0  温差小
# 3  2018-01-04     阴  东北风  1-2级      28    优     1   0.0  -8.0  8.0  温差小
# 4  2018-01-05  多云~晴  西北风  1-2级      50    优     1   3.0  -6.0  9.0  温差小

# %% [markdown]
# 分析天气情况和温差有没有关系
#
# 两种方法分析 ： query & 切片

# %%
df.head()
# Out:
#            日期  天气情况   风向    风力  空气质量指数 空气情况  空气等级  最高温度  最低温度   温差 温差类型
# 0  2018-01-01  晴~多云  东北风  1-2级      59    良     2   3.0  -6.0  9.0  温差小
# 1  2018-01-02  阴~多云  东北风  1-2级      49    优     1   2.0  -5.0  7.0  温差小
# 2  2018-01-03    多云   北风  1-2级      28    优     1   2.0  -5.0  7.0  温差小
# 3  2018-01-04     阴  东北风  1-2级      28    优     1   0.0  -8.0  8.0  温差小
# 4  2018-01-05  多云~晴  西北风  1-2级      50    优     1   3.0  -6.0  9.0  温差小

# %%
# 一共有多少中天气情况
df['天气情况'].unique().shape
# Out:
# (31,)

# %%
df.head()
# Out:
#            日期  天气情况   风向    风力  空气质量指数 空气情况  空气等级  最高温度  最低温度   温差 温差类型  月份
# 0  2018-01-01  晴~多云  东北风  1-2级      59    良     2   3.0  -6.0  9.0  温差小   1
# 1  2018-01-02  阴~多云  东北风  1-2级      49    优     1   2.0  -5.0  7.0  温差小   1
# 2  2018-01-03    多云   北风  1-2级      28    优     1   2.0  -5.0  7.0  温差小   1
# 3  2018-01-04     阴  东北风  1-2级      28    优     1   0.0  -8.0  8.0  温差小   1
# 4  2018-01-05  多云~晴  西北风  1-2级      50    优     1   3.0  -6.0  9.0  温差小   1

# %%
df.query('空气情况=="良"')

# %% [markdown]
# 第一种筛选数据的方式
# # df.query（condition）condition  是一个字符串类型的条件表达式，可以包含各种比较操作符、逻辑操作符和函数等。

# %%
df.query('天气情况=="晴~多云"')
len(df.query('天气情况=="晴~多云"'))

# %% [markdown]
# 第二种 切片操作 ，这里使用显示
# 没办法做多条件约束

# %%
# print(df.loc[df['天气情况']=='晴~多云'])
# len(df.loc[df['天气情况']=='晴~多云'])

# %% [markdown]
# 分组聚合
#  groupby
#  max min avg

# %%
df
# Out:
#              日期  天气情况   风向    风力  空气质量指数 空气情况  空气等级  最高温度  最低温度   温差 温差类型
# 0    2018-01-01  晴~多云  东北风  1-2级      59    良     2   3.0  -6.0  9.0  温差小
# 1    2018-01-02  阴~多云  东北风  1-2级      49    优     1   2.0  -5.0  7.0  温差小
# 2    2018-01-03    多云   北风  1-2级      28    优     1   2.0  -5.0  7.0  温差小
# 3    2018-01-04     阴  东北风  1-2级      28    优     1   0.0  -8.0  8.0  温差小
# 4    2018-01-05  多云~晴  西北风  1-2级      50    优     1   3.0  -6.0  9.0  温差小
# ..          ...   ...  ...   ...     ...  ...   ...   ...   ...  ...  ...
# 360  2018-12-27  多云~晴  西北风    3级      48    优     1  -5.0 -12.0  7.0  温差小
# 361  2018-12-28     晴  西北风    3级      40    优     1  -3.0 -11.0  8.0  温差小
# 362  2018-12-29     晴  西北风    2级      29    优     1  -3.0 -12.0  9.0  温差小
# 363  2018-12-30  晴~多云  东北风    1级      31    优     1  -2.0 -11.0  9.0  温差小
# 364  2018-12-31    多云  东北风    1级      56    良     2  -2.0 -10.0  8.0  温差小
#
# [365 rows x 11 columns]

# %%
data=df['温差'].groupby(df['天气情况']).mean()
data
# Out:
# 天气情况
# 中雨~小雨      4.000000
# 中雨~雷阵雨     5.500000
# 多云        10.357895
# 多云~小雨     11.400000
# 多云~晴      11.600000
# 多云~阴       9.000000
# 多云~雷阵雨     9.285714
# 大雨~小雨      4.000000
# 小雨         7.833333
# 小雨~中雨      5.000000
# 小雨~多云      7.875000
# 小雨~大雨      7.000000
# 小雨~阴       4.000000
# 小雨~雨夹雪     9.000000
# 小雨~雷阵雨     5.000000
# 小雪~多云      7.000000
# 晴         11.693069
# 晴~多云      11.235294
# 暴雨~雷阵雨     2.000000
# 阴          8.500000
# 阴~多云       7.000000
# 阴~小雨       6.500000
# 阴~小雪       5.000000
# 阴~雷阵雨      9.000000
# 雷阵雨        7.625000
# 雷阵雨~中雨     7.250000
# 雷阵雨~多云     8.857143
# 雷阵雨~大雨     3.000000
# 雷阵雨~阴      5.000000
# 雾~多云       7.000000
# 霾          9.000000
# Name: 温差, dtype: float64

# %%
df.groupby(df['天气情况'])['温差'].mean()
df['温差'].groupby(df['天气情况']).mean()
df.groupby('天气情况').agg({'温差':'mean','最低温度':'sum'})

# %%
df.groupby('天气情况')[['温差','最低温度']].mean()
# Out:
#                温差       最低温度
# 天气情况
# 中雨~小雨    4.000000  23.500000
# 中雨~雷阵雨   5.500000  23.500000
# 多云      10.357895   8.989474
# 多云~小雨   11.400000  16.000000
# 多云~晴    11.600000   7.000000
# 多云~阴     9.000000   5.300000
# 多云~雷阵雨   9.285714  23.214286
# 大雨~小雨    4.000000  12.000000
# 小雨       7.833333  15.333333
# 小雨~中雨    5.000000  23.000000
# 小雨~多云    7.875000  13.125000
# 小雨~大雨    7.000000  25.000000
# 小雨~阴     4.000000   0.000000
# 小雨~雨夹雪   9.000000   1.000000
# 小雨~雷阵雨   5.000000  25.000000
# 小雪~多云    7.000000 -10.000000
# 晴       11.693069   3.970297
# 晴~多云    11.235294   3.323529
# 暴雨~雷阵雨   2.000000  26.000000
# 阴        8.500000   0.000000
# 阴~多云     7.000000   3.375000
# 阴~小雨     6.500000  17.500000
# 阴~小雪     5.000000  -5.000000
# 阴~雷阵雨    9.000000  22.000000
# 雷阵雨      7.625000  23.125000
# 雷阵雨~中雨   7.250000  24.000000
# 雷阵雨~多云   8.857143  22.000000
# 雷阵雨~大雨   3.000000  22.000000
# 雷阵雨~阴    5.000000  24.000000
# 雾~多云     7.000000   2.000000
# 霾        9.000000  -5.000000

# %%
df.groupby('天气情况').agg({'温差':'mean','最低温度':'sum'})
# Out:
#                温差   最低温度
# 天气情况
# 中雨~小雨    4.000000   47.0
# 中雨~雷阵雨   5.500000   47.0
# 多云      10.357895  854.0
# 多云~小雨   11.400000   80.0
# 多云~晴    11.600000  280.0
# 多云~阴     9.000000   53.0
# 多云~雷阵雨   9.285714  325.0
# 大雨~小雨    4.000000   12.0
# 小雨       7.833333   92.0
# 小雨~中雨    5.000000   23.0
# 小雨~多云    7.875000  105.0
# 小雨~大雨    7.000000   25.0
# 小雨~阴     4.000000    0.0
# 小雨~雨夹雪   9.000000    1.0
# 小雨~雷阵雨   5.000000   25.0
# 小雪~多云    7.000000  -10.0
# 晴       11.693069  401.0
# 晴~多云    11.235294  113.0
# 暴雨~雷阵雨   2.000000   26.0
# 阴        8.500000    0.0
# 阴~多云     7.000000   27.0
# 阴~小雨     6.500000   35.0
# 阴~小雪     5.000000   -5.0
# 阴~雷阵雨    9.000000   22.0
# 雷阵雨      7.625000  185.0
# 雷阵雨~中雨   7.250000   96.0
# 雷阵雨~多云   8.857143  154.0
# 雷阵雨~大雨   3.000000   22.0
# 雷阵雨~阴    5.000000   24.0
# 雾~多云     7.000000    2.0
# 霾        9.000000  -10.0

# %%
c=(
    Bar(init_opts=opts.InitOpts(width='1200px',height='800px'))
    .add_xaxis(data.index.tolist())
    .add_yaxis('温差',data.values.tolist())
    .set_global_opts(
        title_opts=opts.TitleOpts(title='天气情况和温度之间的关系'),
        datazoom_opts=opts.DataZoomOpts(),
    )

)
c.render_notebook
# Out:
# <bound method Base.render_notebook of <pyecharts.charts.basic_charts.bar.Bar object at 0x0000022E05353C10>>

# %% [markdown]
# # .render("bar base.html") # 把图表绘制到HTML文件

# %%
df.head()
# Out:
#            日期  天气情况   风向    风力  空气质量指数 空气情况  空气等级  最高温度  最低温度   温差 温差类型
# 0  2018-01-01  晴~多云  东北风  1-2级      59    良     2   3.0  -6.0  9.0  温差小
# 1  2018-01-02  阴~多云  东北风  1-2级      49    优     1   2.0  -5.0  7.0  温差小
# 2  2018-01-03    多云   北风  1-2级      28    优     1   2.0  -5.0  7.0  温差小
# 3  2018-01-04     阴  东北风  1-2级      28    优     1   0.0  -8.0  8.0  温差小
# 4  2018-01-05  多云~晴  西北风  1-2级      50    优     1   3.0  -6.0  9.0  温差小

# %%
df['月份']=df['日期'].apply(lambda d:int(d.split('-')[1]))

# %%
df['月份'].map({1:'一',2:'二'})
# Out:
# 0        一
# 1        一
# 2        一
# 3        一
# 4        一
#       ...
# 360    NaN
# 361    NaN
# 362    NaN
# 363    NaN
# 364    NaN
# Name: 月份, Length: 365, dtype: object

# %%
df.head()
# Out:
#            日期  天气情况   风向    风力  空气质量指数 空气情况  空气等级  最高温度  最低温度   温差 温差类型  月份
# 0  2018-01-01  晴~多云  东北风  1-2级      59    良     2   3.0  -6.0  9.0  温差小   1
# 1  2018-01-02  阴~多云  东北风  1-2级      49    优     1   2.0  -5.0  7.0  温差小   1
# 2  2018-01-03    多云   北风  1-2级      28    优     1   2.0  -5.0  7.0  温差小   1
# 3  2018-01-04     阴  东北风  1-2级      28    优     1   0.0  -8.0  8.0  温差小   1
# 4  2018-01-05  多云~晴  西北风  1-2级      50    优     1   3.0  -6.0  9.0  温差小   1

# %%
df_summer=df.query('6<=月份<=8')
df_summer
# Out:
#              日期    天气情况   风向    风力  空气质量指数 空气情况  空气等级  最高温度  最低温度    温差 温差类型  \
# 151  2018-06-01       晴  西南风  3-4级      72    良     2  36.0  21.0  15.0  温差大
# 152  2018-06-02      多云   南风  3-4级      98    良     2  35.0  21.0  14.0  温差大
# 153  2018-06-03      多云   北风  1-2级      92    良     2  32.0  19.0  13.0  温差大
# 154  2018-06-04       晴  西南风  3-4级      69    良     2  35.0  20.0  15.0  温差大
# 155  2018-06-05      多云  西南风  4-5级      94    良     2  38.0  25.0  13.0  温差大
# ..          ...     ...  ...   ...     ...  ...   ...   ...   ...   ...  ...
# 238  2018-08-27  多云~雷阵雨  东南风  1-2级      89    良     2  30.0  22.0   8.0  温差小
# 239  2018-08-28   小雨~多云   南风  1-2级      58    良     2  29.0  22.0   7.0  温差小
# 240  2018-08-29    晴~多云   北风  3-4级      44    优     1  31.0  20.0  11.0  温差大
# 241  2018-08-30      多云   南风  1-2级      47    优     1  29.0  20.0   9.0  温差小
# 242  2018-08-31    多云~阴  东南风  1-2级      48    优     1  29.0  20.0   9.0  温差小
#
#      月份
# 151   6
# 152   6
# 153   6
# ...

# %%
df_summer['天气情况'].unique()
# Out:
# array(['晴', '多云', '多云~雷阵雨', '小雨', '雷阵雨~多云', '阴~雷阵雨', '雷阵雨', '多云~晴',
#        '雷阵雨~大雨', '中雨~雷阵雨', '小雨~大雨', '暴雨~雷阵雨', '晴~多云', '雷阵雨~中雨', '小雨~雷阵雨',
#        '雷阵雨~阴', '中雨~小雨', '小雨~中雨', '多云~小雨', '小雨~多云', '多云~阴'], dtype=object)

# %%
df_summer['天气情况'].nunique()
# Out:
# 21

# %%
data_summer=df_summer['温差'].groupby(df_summer['天气情况']).mean().round(2)
data_summer
# Out:
# 天气情况
# 中雨~小雨      4.00
# 中雨~雷阵雨     5.50
# 多云         9.72
# 多云~小雨      9.00
# 多云~晴      10.33
# 多云~阴       9.00
# 多云~雷阵雨     9.29
# 小雨         6.00
# 小雨~中雨      5.00
# 小雨~多云      7.00
# 小雨~大雨      7.00
# 小雨~雷阵雨     5.00
# 晴         11.70
# 晴~多云       9.67
# 暴雨~雷阵雨     2.00
# 阴~雷阵雨      9.00
# 雷阵雨        7.62
# 雷阵雨~中雨     7.25
# 雷阵雨~多云     8.86
# 雷阵雨~大雨     3.00
# 雷阵雨~阴      5.00
# Name: 温差, dtype: float64
